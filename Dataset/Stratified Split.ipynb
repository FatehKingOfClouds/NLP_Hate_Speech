# %%
import pandas as pd
import os
import glob

# %%
load_path = 'full_data'

# %%
columns = ['text','label']

# %%
if not os.path.exists('train'):
    os.makedirs('train')
if not os.path.exists('val'):
    os.makedirs('val')
if not os.path.exists('test'):
    os.makedirs('test')

# %%
for filename in os.listdir(load_path):
    df = pd.read_csv(os.path.join(load_path,filename))
    df = df[columns]
    train_df_ids = list(pd.read_csv('ID Mapping/train/'+filename)['id'])
    train_df = df.iloc[train_df_ids]
    train_df.to_csv('train/'+filename,index=False)
    val_df_ids = list(pd.read_csv('ID Mapping/val/'+filename)['id'])
    val_df = df.iloc[val_df_ids]
    val_df.to_csv('val/'+filename,index=False)
    test_df_ids = list(pd.read_csv('ID Mapping/test/'+filename)['id'])
    test_df = df.iloc[test_df_ids]
    test_df.to_csv('test/'+filename,index=False)
# Out:
# Processing Arabic_1b_full.csv...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\etulyon1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'HITId'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 15
#      12 test_df_ids = list(pd.read_csv('ID Mapping/test/' + filename)['id'])
#      14 # Use .loc[] with the actual HITId values, not positional indices
# ---> 15 train_df = df[df['HITId'].isin(train_df_ids)]
#      16 train_df.to_csv('train/' + filename, index=False)
#      18 val_df = df[df['HITId'].isin(val_df_ids)]
#
# File c:\Users\etulyon1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File c:\Users\etulyon1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'HITId'
